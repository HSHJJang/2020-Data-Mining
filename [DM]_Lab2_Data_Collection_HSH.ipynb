# %% [markdown]
# ## 인터넷, 웹, 웹 브라우저

# %% [markdown]
# - **인터넷** : 원거리에 퍼져있는 컴퓨터 네트워크를 서로 연결시켜주는 네트워크 시스템
# - **웹** : 인터넷을 기반으로 사람들이 정보를 검색할 수 있는 정보 공간
# - **웹 브라우저** : 웹 문서를 사용자에게 편하게 보여주는 소프트웨어

# %% [markdown]
# ## 우리가 웹사이트에 접속할 때, 일어나는 일

# %% [markdown]
# 1. **URL**이 브라우저에 입력되면, URL (the domain name)이 적절한 웹서버를 찾아서, 웹서버에 **request**를 보냄.
# 2. 서버는 브라우저에 HTML 페이지(+a)를 보냄으로서 **response**함.
# 3. 브라우저는 내부에서 응답받은 HTML을 이용해 DOM (Document Object Model)을 통해 렌더 **트리** (tree representation) 생성
# 4. 생성된 랜더트리는 브라우저를 통해 사용자에게 보여짐.
#
# - \* HTML 외에도 java script (JS), CSS 등이 웹페이지를 보는데 사용됨.
#     - CSS는 HTML 요소들의 스타일을 정의하고
#     - JS는 주로 웹페이지를 동적으로 기능하게 만들어줌. 예를 들어, 이미지 슬라이드 같은 것들.

# %% [markdown]
# ![크롬 브라우저가 웹페이지를 보여주는 과정](https://d2.naver.com/content/images/2015/06/helloworld-59361-3.png)

# %% [markdown]
# #### [Ex] 웹페이지의 HTML document를 요청해서 받아오기

# %%
import requests
url = 'https://ko.wikipedia.org/wiki/%EC%9D%B8%ED%84%B0%EB%84%B7'

# %% [markdown]
# # HTML를 구성하는 요소들

# %% [markdown]
# ![HTML 컨테이너 요소의 일부](https://wikimedia.org/api/rest_v1/media/math/render/svg/9b19f2818482c6618c82e23b4e6a5a3a4d94c57d)

# %% [markdown]
# - HTML 컨테이너 요소의 일부 (source : [HTML 요소 by 위키피디아](https://ko.wikipedia.org/wiki/HTML_요소))

# %% [markdown]
# - tags = 'p'
#     - HTML은 <p\> 시작태그와 </p\> 종료태그를 항상 포함함.
# - attributes : { 'class' = 'foo' }
#     - HTML 요소의 특성을 설정하는 구체적인 명령어들로 class 이외에 name, value 등이 자주 쓰임.

# %% [markdown]
# # Selecting HTML elements with BeautifulSoup
# - 간단한 웹페이지는 BeautifulSoup이라는 패키지를 통해 불러올 수 있음

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# #### [EX] 웹 테이블 형태의 텍스트를 python 자료형으로 바꾸기
# - "2009년 기준, 세계 10대 인터넷 다운로드 전송 속도"와 관련된 자료를 불러오세요

# %% [markdown]
# # Selecting HTML elements with Selenium + Chromedriver

# %% [markdown]
# - 어떤 사이트의 경우, 어떤 조건(경우마다 다름)이 충족되어야지 볼 수 있는 웹사이트가 있음.
# - 혹은 로그인 한다음,  특정 정보를 가져와야한다던가,  검색어를 통해 해야한다던가 하는 경우
# - 이럴 때 쓸 수 있는 방법 중 하나가 셀레늄+크롬드라이버를 사용하는 것.

# %% [markdown]
# - 환경셋팅
#     -  로컬에서 작업시
#         1. selenium 설치 : pip install selenium & 크롬 웹브라우저 설치
#         2. [크롬환경설정](chrome://settings/help) 에서 본인 크롬 버젼 확인
#         3. [chromdriver 다운로드](http://chromedriver.chromium.org) 후, 다운한 파일을 현재 작업 중인 파일과 같은 폴더에 두기
#         4.  selenium을 import
#         5.  webdriver를 통해 웹브라우저 오픈
#         ```
#         driver = webdriver.Chrome('chromedriver')
#         ```
#
#     -  Colab에서 작업시
#         1.  관련 package  설치
#
#         ```
#         !apt-get update
#         !apt install chromium-chromedriver
#         !pip install selenium
#         ```
#
#         2.  selenium을 import한 뒤에,  headless 설정
#
#         ```
#         from selenium import webdriver
#         options = webdriver.ChromeOptions()
#         options.add_argument('--headless')
#         options.add_argument('--no-sandbox')
#         options.add_argument('--disable-dev-shm-usage')
#         ```
#
#         3.  webdriver를 통해 웹브라우저 오픈
#         ```
#         driver = webdriver.Chrome('/usr/bin/chromedriver', options=options)
#         ```

# %%
# !apt-get update
# !apt install chromium-chromedriver
# !pip install selenium

# %%
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

# %%
driver = webdriver.Chrome('/usr/bin/chromedriver', options=options)

# %% [markdown]
# - 코로나-19  중앙방역대책본부 브리핑 모아보기
# - 정부브리핑 리스트: http://www.korea.kr/news/policyBriefingList.do
# - 4월 8일 중앙방역대책본부 브리핑: http://www.korea.kr/news/policyBriefingView.do?newsId=156384579&pageIndex=1&srchType=&startDate=2008-02-29&endDate=2020-04-08&srchWord=

# %%
url = "http://www.korea.kr/news/policyBriefingView.do?newsId=156384579&pageIndex=1&srchType=&startDate=2008-02-29&endDate=2020-04-08&srchWord="
driver.get(url)

# %%
title = driver.find_element_by_xpath('//*[@id="container"]/div/article/div[1]/h1')
speaker = driver.find_element_by_xpath('//*[@id="container"]/div/article/div[1]/div[1]/span[1]')
date = driver.find_element_by_xpath('//*[@id="container"]/div/article/div[1]/div[1]/span[2]')
body = driver.find_element_by_xpath('//*[@id="container"]/div/article/div[2]/div[1]')

# %%
title.text
# Out:
# '중앙방역대책본부 정례브리핑'

# %% [markdown]
# #### 자동으로 검색해서,  원하는 결과만 불러오기

# %%
url = "http://www.korea.kr/news/policyBriefingList.do"
driver.get(url)

# %%
input_ = driver.find_element_by_xpath('//*[@id="srchWord"]')
input_
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="47aa68b384fa8ebc6067273a1fce3cbd", element="b82dfe3e-ed53-4d4f-b6e1-07a133f95870")>

# %%
input_.send_keys('중앙방역대책본부')

# %%
btn = driver.find_element_by_xpath('//*[@id="mainForm"]/fieldset/div[2]/button')
btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="47aa68b384fa8ebc6067273a1fce3cbd", element="1457206f-ade0-43c0-bbb4-b8fdd366118c")>

# %%
btn.click()

# %%
pages_url = driver.find_elements_by_xpath('//*[@id="container"]/div/article/div[1]/table/tbody/tr/td[2]/a')
len(pages_url)
# Out:
# 30

# %%
brief_url = []
for page in pages_url:
  brief_url.append(page.get_attribute('href'))

# %%
page_2 = driver.find_element_by_xpath('//*[@id="container"]/div/article/div[1]/div[2]/span[2]/a')
page_2.click()

# %%
pages_url = driver.find_elements_by_xpath('//*[@id="container"]/div/article/div[1]/table/tbody/tr/td[2]/a')
for page in pages_url:
  brief_url.append(page.get_attribute('href'))
len(brief_url)
# Out:
# 60

# %%
page_3 = driver.find_element_by_xpath('//*[@id="container"]/div/article/div[1]/div[2]/span[3]/a')
page_3.click()

# %%
pages_url = driver.find_elements_by_xpath('//*[@id="container"]/div/article/div[1]/table/tbody/tr/td[2]/a')
for page in pages_url:
  brief_url.append(page.get_attribute('href'))
len(brief_url)
# Out:
# 79

# %%
def ele_to_text(url):
  driver.get(url)

  title = driver.find_element_by_xpath('//*[@id="container"]/div/article/div[1]/h1')
  speaker = driver.find_element_by_xpath('//*[@id="container"]/div/article/div[1]/div[1]/span[1]')
  date = driver.find_element_by_xpath('//*[@id="container"]/div/article/div[1]/div[1]/span[2]')
  body = driver.find_element_by_xpath('//*[@id="container"]/div/article/div[2]/div[1]')

  return{
      'title': title.text,
      'speaker': speaker.text,
      'date': date.text,
      'body': body.text
  }

# %%
from tqdm import tqdm

# %%
import time
from tqdm.notebook import tqdm

data = []

pbar = tqdm(range(len(brief_url)))

for url in brief_url:
  d = ele_to_text(url)
  data.append(d)
  time.sleep(3)
  pbar.update()
  
pbar.close()
# Out:
# HBox(children=(IntProgress(value=0, max=79), HTML(value='')))

# %%
import pandas as pd

df = pd.DataFrame(data)
df.to_csv('covid_19_brief.csv')

# %% [markdown]
# - 안정적인 크롤링을 위한 XPath 팁
#     - 인덱스 형태 '//*[@id="cbox_module"]/div/div[2]/ul/li/div/div\[2]/div' 의 XPath 지양 : 웹페이지 디자인 변화(광고의 추가라던가)에 취약
#     - 코드 가독성이 떨어짐 (저번주의 나는 무엇을 짠건가....,  나의 팀원은 무엇을  짠건가....)
#     - xpath를 바꾸거나, `find_elements_by_class_name`, `find_elements_by_name` 등 가독성이 좀 더 나은 함수를 사용하자

# %% [markdown]
# ```
# - $x('/html/head/title') : 트리의 절대적인 위치대로 접근. 제일 상위에 있는 순서대로. html > head > title
# - $x('//h1') : 트리의 상대적인 위치대로 접근. h1이 위치하든 상관없고 태그가 h1이면됨.
# - $x('//h2') : 이것도 h2 태그에 접근하는 방식
# - $x('//h2/span') : 위치에 상관없이 h2에 접근한 위, 그 하위에 있는 span에 접근
# - $x('//h2/span[@class="mw-headline"]') : 위치에 상관없이 h2에 접근한 뒤, 그 하위에 있는 span에 접근 + class 속성 이름이 "mw-headline"이어야 함.
# - $x('//*[@class="mw-headline"]') : 위치에 상관없이 class 속성 이름이 "mw-headline"인 요소에 접근
# - $x('//h2/span[@class="mw-headline"]/text()') : 위치에 상관없이 h2에 접근한 뒤, 그 하위에 있는 span에 접근 + class 속성 이름이 "mw-headline"인 요소의 텍스트 값에 접근
# - $x('//h2/span[contains(@class, "headline")]'): 위치에 상관없이 h2에 접근한 뒤, 그 하위에 있는 span에 접근 + class 속성 이름에 "headline"을 포함하고 있는 요소에 접근
# ```

# %%
title = driver.find_element_by_xpath('//article/div[@class="article-head"]/h1')
speaker = driver.find_element_by_xpath('//article/div[@class="article-head"]/div[@class="info"]/span[1]')
date = driver.find_element_by_xpath('//article/div[@class="article-head"]/div[@class="info"]/span[2]')
body = driver.find_element_by_xpath('//article/div[@class="article-content"]/div[@class="view-cont"]')

# %%
speaker.text
# Out:
# '권준욱 중앙방역대책본부 부본부장'

# %% [markdown]
# ---

# %% [markdown]
# # Twitter

# %%
! pip install twint
# Out:
# Collecting twint
#   Downloading https://files.pythonhosted.org/packages/c5/d3/5a249973e0fdd5af1e505680e63ec1041ebba52a8b1dd12b758711c7201c/twint-2.1.19.tar.gz
# Collecting aiohttp
#   Downloading https://files.pythonhosted.org/packages/7c/39/7eb5f98d24904e0f6d3edb505d4aa60e3ef83c0a58d6fe18244a51757247/aiohttp-3.6.2-cp36-cp36m-manylinux1_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 15.0MB/s
# Collecting aiodns
#   Downloading https://files.pythonhosted.org/packages/da/01/8f2d49b441573fd2478833bdba91cf0b853b4c750a1fbb9e98de1b94bb22/aiodns-2.0.0-py2.py3-none-any.whl
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from twint) (4.6.3)
# Collecting cchardet
#   Downloading https://files.pythonhosted.org/packages/1e/c5/7e1a0d7b4afd83d6f8de794fce82820ec4c5136c6d52e14000822681a842/cchardet-2.1.6-cp36-cp36m-manylinux2010_x86_64.whl (241kB)
#      |████████████████████████████████| 245kB 52.5MB/s
# Collecting elasticsearch
#   Downloading https://files.pythonhosted.org/packages/cc/cf/7973ac58090b960857da04add0b345415bf1e1741beddf4cbe136b8ad174/elasticsearch-7.6.0-py2.py3-none-any.whl (88kB)
#      |████████████████████████████████| 92kB 11.6MB/s
# Requirement already satisfied: pysocks in /usr/local/lib/python3.6/dist-packages (from twint) (1.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from twint) (1.0.3)
# Collecting aiohttp_socks
#   Downloading https://files.pythonhosted.org/packages/06/28/67fcf0de9046f98052a30e0d8dc2529d8662b18f78b92eea42d7048a5e80/aiohttp_socks-0.3.9-py3-none-any.whl
# Collecting schedule
#   Downloading https://files.pythonhosted.org/packages/57/22/3a709462eb02412bd1145f6e53604f36bba191e3e4e397bea4a718fec38c/schedule-0.6.0-py2.py3-none-any.whl
# Requirement already satisfied: geopy in /usr/local/lib/python3.6/dist-packages (from twint) (1.17.0)
# Collecting fake-useragent
#   Downloading https://files.pythonhosted.org/packages/d1/79/af647635d6968e2deb57a208d309f6069d31cb138066d7e821e575112a80/fake-useragent-0.1.11.tar.gz
# Collecting googletransx
#   Downloading https://files.pythonhosted.org/packages/27/e1/77cd530afec7944d40c5bdd260bcc111be4012b045c82d4e3ffec90b2a42/googletransx-2.4.2.tar.gz
# Collecting yarl<2.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/95/8f/0209fc5d975f839344c33c822ff2f7ef80f6b1e984673a5a68f960bfa583/yarl-1.4.2-cp36-cp36m-manylinux1_x86_64.whl (252kB)
#      |████████████████████████████████| 256kB 46.6MB/s
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->twint) (3.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->twint) (19.3.0)
# Collecting multidict<5.0,>=4.5
#   Downloading https://files.pythonhosted.org/packages/30/2e/3ab2f1fb72571f75013db323a3799d505d99f3bc203513604f1ffb9b7858/multidict-4.7.5-cp36-cp36m-manylinux1_x86_64.whl (148kB)
#      |████████████████████████████████| 153kB 46.4MB/s
# Collecting async-timeout<4.0,>=3.0
#   Downloading https://files.pythonhosted.org/packages/e1/1e/5a4441be21b0726c4464f3f23c8b19628372f606755a9d2e46c187e65ec4/async_timeout-3.0.1-py3-none-any.whl
# Requirement already satisfied: typing-extensions>=3.6.5; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->twint) (3.6.6)
# Collecting idna-ssl>=1.0; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/46/03/07c4894aae38b0de52b52586b24bf189bb83e4ddabfe2e2c8f2419eec6f4/idna-ssl-1.1.0.tar.gz
# Requirement already satisfied: typing; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiodns->twint) (3.6.6)
# Collecting pycares>=3.0.0
#   Downloading https://files.pythonhosted.org/packages/43/2d/7f4984a23f6e99cf6a8b20ddc59308efb209fe81e79c97af65e9b30eefae/pycares-3.1.1-cp36-cp36m-manylinux2010_x86_64.whl (228kB)
#      |████████████████████████████████| 235kB 44.7MB/s
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from elasticsearch->twint) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->twint) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->twint) (2018.9)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas->twint) (1.18.3)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.6/dist-packages (from geopy->twint) (1.50)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from googletransx->twint) (2.21.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.6/dist-packages (from yarl<2.0,>=1.0->aiohttp->twint) (2.8)
# Requirement already satisfied: cffi>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pycares>=3.0.0->aiodns->twint) (1.14.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas->twint) (1.12.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->googletransx->twint) (2020.4.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.5.0->pycares>=3.0.0->aiodns->twint) (2.20)
# Building wheels for collected packages: twint, fake-useragent, googletransx, idna-ssl
#   Building wheel for twint (setup.py) ... done
#   Created wheel for twint: filename=twint-2.1.19-cp36-none-any.whl size=33519 sha256=82ebbe8205a4a89901369b362b093d15236c4d8c7e7b5bac4650a5c62ba8826a
#   Stored in directory: /root/.cache/pip/wheels/cf/d1/88/bebb59d5991c3744d4aecda0a6491e6ec22259ea85eb6e9a31
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-cp36-none-any.whl size=13484 sha256=ba98d8f60426b1e607788b16d221d1b8fd85e6d3022d657c7458ad6dcb7873a6
#   Stored in directory: /root/.cache/pip/wheels/5e/63/09/d1dc15179f175357d3f5c00cbffbac37f9e8690d80545143ff
#   Building wheel for googletransx (setup.py) ... done
#   Created wheel for googletransx: filename=googletransx-2.4.2-cp36-none-any.whl size=15969 sha256=da8ee7d2b2920bba5e4d2fdac646858ad993cfb10d8c58b4c0fc987f07edbb0a
#   Stored in directory: /root/.cache/pip/wheels/04/63/5f/75e7e94eb62517946116a783e4cd8970c4789c990bbc732616
#   Building wheel for idna-ssl (setup.py) ... done
#   Created wheel for idna-ssl: filename=idna_ssl-1.1.0-cp36-none-any.whl size=3162 sha256=a3869116e73d5ef22d37a8383a20da3e33fa7329fa4d8505a9e2f1d7d5e4acad
#   Stored in directory: /root/.cache/pip/wheels/d3/00/b3/32d613e19e08a739751dd6bf998cfed277728f8b2127ad4eb7
# Successfully built twint fake-useragent googletransx idna-ssl
# Installing collected packages: multidict, yarl, async-timeout, idna-ssl, aiohttp, pycares, aiodns, cchardet, elasticsearch, aiohttp-socks, schedule, fake-useragent, googletransx, twint
# Successfully installed aiodns-2.0.0 aiohttp-3.6.2 aiohttp-socks-0.3.9 async-timeout-3.0.1 cchardet-2.1.6 elasticsearch-7.6.0 fake-useragent-0.1.11 googletransx-2.4.2 idna-ssl-1.1.0 multidict-4.7.5 pycares-3.1.1 schedule-0.6.0 twint-2.1.19 yarl-1.4.2

# %% [markdown]
# ##  검색어 기반으로 데이터 모으기

# %%
import twint

c = twint.Config()
c.Store_csv = True
c.Output = 'twitter.csv'
c.Search = '라라랜드'
c.Limit = 50

twint.run.Search(c)
# Out:
# 1254385087514152963 2020-04-26 12:21:24 UTC <Ravithepink> 아니 저 발펄짝 저거 라라랜드에서 그 그거 아니냐
# 1254382816361504768 2020-04-26 12:12:23 UTC <jin_jin_0516> 라라랜드! 작은 아씨들! 벼랑위의 포뇨! 파퍼씨네 펭귄들! 마틸다! 나니아 연대기 정주행! 해리포터 정주행! 숲속으로!
# 1254380358604165126 2020-04-26 12:02:37 UTC <ebxrhdiddl> 저 티엠아인데 라라랜드 나온 라이언 고슬링이랑 생일 똑같아요
# 1254376215495864322 2020-04-26 11:46:09 UTC <hev_er> 라라랜드 첨으로 끝까지 제대로 보고 찔 짜는중  pic.twitter.com/xLZ5uvoub1
# 1254375274587676673 2020-04-26 11:42:25 UTC <eunyou_7> 노을이 지는 하늘이 아름다워  친구가 "인프피는 라라랜드속에 산다" 라고 얘기를 했다. 꺄 너무 좋잖아💃  pic.twitter.com/TBKlsskSrc
# 1254374691394867201 2020-04-26 11:40:06 UTC <maeillrecord> 라라랜드 그냥 소장용으로 살까봐 없으면 안돼 ...
# 1254374474880659457 2020-04-26 11:39:14 UTC <ceruleum_sch> 이걸로 해보고 에델이 이런 얼굴형이라도 ㄱㅊ읅 것 같으면 정착하고 아니면 라라랜드 이후 다시 돌아오려구요ㅋㅋㅋㅋㅋㅋㅋㅋ
# 1254373490150346752 2020-04-26 11:35:19 UTC <whitefish222> 라라랜드 존잼..... 근데 결말이... 😊😢 얘네들이 춤출때마다 자꾸 눈물 났는데 사실 예견된 결말에 대한 눈물이었던거 아닐까..  pic.twitter.com/SutiXMcbBj
# 1254372356690075648 2020-04-26 11:30:49 UTC <SH__all4u> 제 최애 영화 2개가 어바웃타임이랑 라라랜드에다가 서노 입덕 계기가 래완이인데 어바웃타임 대사와 래완이의 만남이라니요•• 으내님 진짜 은혜로워요•• 제 잠금화면도 전에 으내님이 올려주셨던 건데 폰배경 이걸로 당장 바꿨어요 ◡̈ 카톡 테마도 넘 잘 쓰고 있어요 ༘♡
# 1254372072576258048 2020-04-26 11:29:41 UTC <Xiahholiclady> 이 와중에 라라랜드 보러옴~ 처음본다~
# 1254369644569190400 2020-04-26 11:20:02 UTC <kimkongna_R2> 라라랜드....보고옴. 관계없는 갱얼쥐얼빡  pic.twitter.com/4sOW4LXKfF
# 1254363656231325696 2020-04-26 10:56:15 UTC <JIYE_drawing> COC <Swing with Cinderella> 이시다 타쿠야 KPC로 다녀옵니다. 영롱한 세션카드는 유수님이 만들어 주셨습니다ㅠㅠ 정말 최고야...😭 시나리오 상 KPC가 존잘미인이어야 되서 깐 머리 인장으로 힘 좀 줬다네요(ㅋㅋ) 다들 상큼한 라라랜드 미카게 인장을 봐주자🥰💕  pic.twitter.com/mXUuAmbxge
# 1254356511096074240 2020-04-26 10:27:51 UTC <LeBlanc_SS2> 사실 엠마는 라라랜드 미아보다 어메이징스파이더맨의 그웬이 훨씬 더 좋았어. 엠마는 그 예쁜 얼굴을 가끔 말도 못하게 엉망으로 쓸때가 있어서...(머리짚
# 1254355940440043520 2020-04-26 10:25:35 UTC <callmetwooo> 라라랜드 보러 왔다  pic.twitter.com/XYfr1BXW5F
# 1254351779594039296 2020-04-26 10:09:03 UTC <you_jjing> 5월2일 라라랜드
# 1254348977387868161 2020-04-26 09:57:55 UTC <lesxxxn> 아 라라랜드 좋아
# 1254341810681376768 2020-04-26 09:29:26 UTC <Sum_girl_1> 사실 라라랜드 본 적 없습니다 노래는 좋아하는데 아직 못 봄
# 1254332180848762880 2020-04-26 08:51:10 UTC <N723A511> 라라랜드보고왔고 존나게재밌다  pic.twitter.com/EbKCrcUI4X
# 1254330836255531008 2020-04-26 08:45:50 UTC <callmetwooo> 그냥 라라랜드 보러 가기로 했다 ｡•́‿•̀｡ 재밌었음 좋겠그랴
# 1254329164498300928 2020-04-26 08:39:11 UTC <seungjaegi> 서비스업ex.카페알바영화관알바 이런거존나잘어울림 랄라블라한명이요  네? 라라랜드 말씀하시는거죠 고객님~ㅎㅎ
# 1254326136231747584 2020-04-26 08:27:09 UTC <vBBDDv_> 쫌자다가 코노때리고 라라랜드 보러가야지  하하하하하하 나 오늘개쳐놀거임 깐순아 안돼! 진심이야 나랑놀자
# 1254320236477607937 2020-04-26 08:03:43 UTC <goodag_yes> 라라랜드... 영화관에서 보고파.....
# 1254313115748978688 2020-04-26 07:35:25 UTC <SUPERGSGRm> 아 너무웃겨 배경... 라라랜드 세계관에 갇힌 투패스트 유닛
# 1254309653019652096 2020-04-26 07:21:39 UTC <ham4611> 라라랜드_08. 원래는 아홉번째를 끝냈어야하는 주인데 이사와 외주를 하다보니까 흐름도 끊기고 의욕도 끊겨서 밀렸다.... 😇😇색이 섞이는 브러쉬를 썼는데 좀더 색에 집중하고 싶어서 이번엔 잘 섞이지 않는 브러쉬로 바꿔봤다.  pic.twitter.com/gN1PsxR8xj
# 1254307726252847109 2020-04-26 07:14:00 UTC <malfi_jinsim> 라라랜드에서 젤 이해 못하겠는 장면을... 보고서로 써야 한다니 염병
# 1254306555370995713 2020-04-26 07:09:21 UTC <wldmsk1> 어제찍은 사진🌟  하늘 얘기로 프메답장받은 기억이 나네 😊 어제 완전 얇은 초승달이 떠있더라구 너무 예뻐서 채여니 보여주고 싶어서 냉큼 찍었지! 폰배경화면할까 하다가 채연이가 보내준 배경화면 선물들에 나도 보답하고싶어서 없는 솜씨로 만들어봤오💜약간 라라랜드 색감나지ㅎㅎ #Dear_이채연 pic.twitter.com/j80kkcaG5A
# 1254304321442742273 2020-04-26 07:00:28 UTC <zhskx1> 라라랜드 영화 소개   http://post.naver.com/viewer/postView.nhn?memberNo=5071776&volumeNo=28092949 …
# 1254302523915034624 2020-04-26 06:53:20 UTC <hanryangtori> 뒤늦게 라라랜드 봤는데 엔딩 무슨일..!!
# 1254302259086651392 2020-04-26 06:52:17 UTC <sjsy11061106> 턴테!!! 내 첫 바이닐은 라라랜드로 살거야ㅜㅜㅜ 라라랜드 파랑색 바이닐 ㅜㅜㅜ  그거랑 아델 21 앨범이랑 콜플 바이닐이랑 테일러도 lover 도 괜찮은 것 같고 샘 스미스도 ㅠㅠ
# 1254302035714834432 2020-04-26 06:51:23 UTC <Hi_Yamt> 헉 저두요 라라랜드 안그래도 잇던데 노래가 좋대서???
# 1254296636039155714 2020-04-26 06:29:56 UTC <JH___W1> 재환 직캠 재환 신의목소리 재환 코디북 재환 움짤 재환 gif 재환 방얼 재환 손 재환 신목 재환 잊을게 재환 미안해 재환 라라랜드 재환 불명 재환 불후의명곡 재환 후드티 재환 후드 재환 인형 재환 묵주반지 재환 위드미 재환 나야나 재환 음색
# 1254296481994911744 2020-04-26 06:29:19 UTC <ww_blues> 말도않되. 라라랜드 좋아하는사람 여기 없을줄
# 1254295592827682818 2020-04-26 06:25:47 UTC <ww_blues> 미안 내가 사랑어쩌구영화를 별로안좋아하나봐 라라랜드 장르때문에 약간 그런듯
# 1254295098038251520 2020-04-26 06:23:49 UTC <ww_blues> 진짜라라랜드극혐...
# 1254293431561543680 2020-04-26 06:17:12 UTC <nzC9EYK85G7mDYR> 나... 근데 정말 라라랜드나 맘마미아 같은 영화 좋아하는데 (이성애는규탄한다) 많이나왔음좋겠다 다섯번씩 보게 영화관서
# 1254292672862236672 2020-04-26 06:14:11 UTC <qrtlifecrisis> 상가들이 저층이고 라라랜드처럼 생겼다
# 1254290708036349952 2020-04-26 06:06:23 UTC <_seung__h> 2020.04.25 토요일 밤의 영화산책 <영화의 숲> - 이번 주 영화 🎬찬실이는 복도 많지 🎬라라랜드 - #음악숲정승혼입니다 #음악의숲 #정승환 #영화의숲 #찬실이는복도많지 #강말금 #윤여정 #김영민 #라이언고슬링 #엠마스톤 #박혜은 #더스크린 pic.twitter.com/W3mqKtQumc
# 1254289237609811968 2020-04-26 06:00:32 UTC <yoonimnim> 내일.. 라라랜드보러가ㄲㅏ....?
# 1254289092981870598 2020-04-26 05:59:57 UTC <8vXLY75hLFdWqMT> 라라랜드 오슷 들으면서 산책하기
# 1254281286757126144 2020-04-26 05:28:56 UTC <marmelo_darling> Time 조용하게 시작했다가 중간에 엄청 웅장했다가 끝에 다시 딱 피아노건반으로 줄어드는 거 넘 좋아. ..명곡은 대체로 그런 듯 같은주제로 이렇게 다양한 느낌 줄 수 있고 음 몇 개로 나를 그 순간으로 되돌리는 게(라라랜드 생각
# 1254279666623410179 2020-04-26 05:22:30 UTC <vxxlxlx> 라라랜드 재개봉한거 또보러가고싶네 미국에있을때 극장에서 봤는데
# 1254278295975129088 2020-04-26 05:17:03 UTC <EIIFTDITMG> 어이없는 일 ... 라라랜드 파일로 사려고 네이버 시리즈온 갓는데 40% 할인 쿠폰 주길래 얼마지? 했는데 1000원이엇음 ㅡㅡ 할인 받아서 600원에 삼
# 1254271523268907008 2020-04-26 04:50:09 UTC <BreakNewsCom> ‘라라랜드’, 9일 연속 박스오피스 1위 차지..코로나19 여파 영화관 ‘침체’   / 브레이크뉴스   https://www.breaknews.com/726899
# 1254260018305589250 2020-04-26 04:04:26 UTC <dlfmaqnfaud> 이런 날씨에 라라랜드 오에스티 들으면서 퇴근하니까 진짜 기분 개 째짐
# 1254255619822850048 2020-04-26 03:46:57 UTC <YOMBURGER> 아 헐 80년대 스타일 진짜 잘 어울린다 데이브 막..60-80년대 스타일 잘 어울릴 것 같지 않아요? 좀 라라랜드 스타일..(막)ㅋㅋㅋㅋㅋㅋㅋ핏져는....핏져는......음.....맛있는 캐임(할말이없어서아무말이나함
# 1254244634710048768 2020-04-26 03:03:18 UTC <Oldman_the_sea> 세상에 더 없을 라라랜드  pic.twitter.com/AlSPhnPsoR
# 1254240370906431489 2020-04-26 02:46:21 UTC <yyangdd0o0> #뱃지양도 #뱃지 #라라랜드 #lalaland #두아리파 #dualipa
# 1254240145953284097 2020-04-26 02:45:28 UTC <yyangdd0o0> <<뱃지양도>  1. 라라랜드 lp - ￦ 7,000  2. 두아리파 - ￦ 8,000 (첫내한 펜타포트)  pic.twitter.com/EyavO1SoE6
# 1254236711598485504 2020-04-26 02:31:49 UTC <pok825666> 라라랜드, 이터널선샤인 추천드려봐요 🙂
# 1254226401865027589 2020-04-26 01:50:51 UTC <gwak_du8> 미쳤나 라라랜드 상영관 반넘게 차서 못보겠음 미친거아녀
# 1254225831682924544 2020-04-26 01:48:35 UTC <shy_dahae_0712> 이시국에 엄마랑 영화 보러 와써여~! 라라랜드 재개봉!! 한동안 답장 없어요()?  #팝콘 #냠냠 #이시국 #라라랜드 #재개봉 #코로나19 pic.twitter.com/Ks2pv5fh15
# 1254225003207221249 2020-04-26 01:45:17 UTC <gwak_du8> 아 아빠가 라라랜드 보고 별로라해서 영화관가기 귀찮아짐....하...
# 1254224035832926210 2020-04-26 01:41:27 UTC <ffnamool> 존재도 몰랐는데 냑자가 라라펠 했으니 라라랜드 가야한다며 손잡고 델구 가줌 ㅋㅋㅋㅋㅋ ㅋㅋㅋ
# 1254223980669497345 2020-04-26 01:41:14 UTC <narr_in> 결국 내일 레슨 끝나고 라라랜드 보러 가기로 했다 🤍🤍
# 1254216980497747968 2020-04-26 01:13:25 UTC <callmetwooo> 라라랜드 보러 서면 갈려고 했는데 확진자 동선에 서면도 있어서 그냥 자가격리 하기로 했다..^!^
# 1254214664352722944 2020-04-26 01:04:12 UTC <ffnamool> 라라랜드  pic.twitter.com/Dq156Wp5iZ
# 1254205531482288128 2020-04-26 00:27:55 UTC <myeongjjang> 오늘도 라라랜드 보러가야지
# 1254135777979588610 2020-04-25 19:50:44 UTC <SB_kumu> 아무래도 알비나 라라랜드에 나온 블루 드레스 입혀야겠음 가자 비즈니스 데이트 수행하러!!
# 1254135494692048896 2020-04-25 19:49:37 UTC <SB_kumu> 아 왜 나 자꾸 라라랜드 재질 뽕이 안빠지지
# 1254129867332874240 2020-04-25 19:27:15 UTC <MayZoo_luna522> 라라랜드 추천드려요!

# %% [markdown]
# ##  특정유저의 follower, following 검색하기

# %%
c = twint.Config()
c.Store_csv = True
c.Output = 'twitter_follower.csv'
c.Username = 'ifcilling'
c.Limit = 30

twint.run.Followers(c)
# Out:
# mzcC39pTXIRYKaG
# nalsumshop
# namooo1216
# playingkids_
# Tenten_Miruku
# ShinnSamuel
# Rosa_in_youmu
# kana509
# Cyan_Sol_
# noznoz1216
# Lynne_DTOSFN
# 0_156_
# mosimo_k_
# sweet_ruby2019
# MOKATE054
# animalsfile
# BeautifulArt14
# Populars_Pups
# egg9871
# drrdishu
# _POP_STEP_GET_U
# xoclaiire
# PrismGamingUK
# cospre_on
# _KOVAN_
# GodOfMischief9
# Wm5FYH0fgOcgiyT
# I_am_Beru
# do119119
# 118ddona0309
# ekctu
# Katou_photograp
# lovelyddona
# MarvelOfRogers
# Lynne_cos
# haji_co1
# komomou
# qamNIj0NsWV8gCf
# D5KiPmiRKCO7sAg
# ceylon_2413

# %%
c = twint.Config()
c.Store_object = True
c.Username = 'ifcilling'
c.Limit = 30

twint.run.Following(c)
# Out:
# namooo1216
# seoul_dessert
# kokuma28
# arashi5official
# Tenten_Miruku
# hopegamewinner
# miyari_s
# osafune_club
# busan_levels
# My_S_ss_
# kana509
# Cyan_Sol_
# noznoz1216
# seseongintern
# pls_painkiller
# L_S_A_0521
# mapadubu0505
# Haim_105
# _seontae
# Hada_00
# TT__TT_TT_TT
# yolo3025
# 99S29
# oT_Touki
# Lynne_DTOSFN
# post_sss
# sesung_PR
# 0_156_
# mosimo_k_
# spi_bot_william
# 2BA_yuu
# ryousei_tanaka
# okamiya_kurumu
# nakadahiroki
# shogo_tamura
# MOKATE054
# nattu515
# 22cats_fanbot
# gingastar1125
# ORANGEJIN

# %%
followings = twint.output.follows_list

# %% [markdown]
# # Instagram
# 1. 로컬 컴퓨터에서 터미널(윈도우는 파워쉘)을 켜서 `pip install instalooter`
# 2. 설치 이후,  터미널에서 영상을 보면서 실습 진행

# %%
# ! pip install instalooter

# %% [markdown]
# ##  특정 유저의 프로필 다운로드
#
# -  아래 셀에는 터미널 명령어를 적어주세요

# %%
# instalooter user cdcgov ./ -n 10
# cdcgov라는 특정유저의 프로필에 있는 정보들을 10개 다운로드
# instalooter user cdcgov ./ -n 10 --dump-only
# 정보를 json형태로 받아옴

# %% [markdown]
# ##  특정 해시태그로 검색한 결과 다운로드
#
# -  아래 셀에는 터미널 명령어를 적어주세요

# %%
# instalooter hashtag "사회적거리두기" ./ -n 20
# 위와 비슷한 기능
# dump only하면 마찬가지로 json으로 받아올 수 있음
